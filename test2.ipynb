# %% [markdown]
# <a href="https://colab.research.google.com/github/zzandie/colab/blob/main/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/datahub-ir/courses/main/mini%20course/plotly/code/Datasets/canada.csv
# Out:
# --2024-03-09 06:00:46--  https://raw.githubusercontent.com/datahub-ir/courses/main/mini%20course/plotly/code/Datasets/canada.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40913 (40K) [text/plain]
# Saving to: ‘canada.csv’
#
# canada.csv          100%[===================>]  39.95K  --.-KB/s    in 0.004s
#
# 2024-03-09 06:00:46 (8.68 MB/s) - ‘canada.csv’ saved [40913/40913]

# %%
import pandas as pd
data = pd.read_csv('canada.csv', engine='python', error_bad_lines = False)
data.head()
# Out:
# <ipython-input-2-4c6a7d0478f0>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('canada.csv', engine='python', error_bad_lines = False)
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# ...
